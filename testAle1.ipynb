# %% [markdown]
# # Base: Algorithm 1

# %% [markdown]
# **Imports**

# %%
import utils as u
import models_generator as mod
import data_generator as dat
import analysis_generator as ana
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       2 import models_generator as mod
#       3 import data_generator as dat
# ----> 4 import analysis_generator as ana
#
# File ~/vs_code/MobDeeper/MobDeep/analysis_generator.py:9
#       6 import pandas as pd
#       8 from keras.models import Sequential, load_model
# ----> 9 from keras.optimizers import Adam
#      10 from keras.layers import LSTM, Dense, GRU
#      11 from keras.callbacks import EarlyStopping
#
# ImportError: cannot import name 'Adam' from 'keras.optimizers' (/home/liale/vs_code/MobDeeper/MobDeep/.conda/lib/python3.9/site-packages/keras/optimizers.py)

# %% [markdown]
# # Generate Model

# %%
modelType = "timegan"
model = "timegan_exp1.json"
exp_settings = u.load_experiment(model)
exp_id = exp_settings['exp_id']
print (exp_id)
print (exp_settings['tests'].keys())
u.creat_directories(exp_id, exp_settings)
mod.train_models("timegan", exp_settings)

# %% [markdown]
# # Generate Synthdata

# %%
dat.synth_data(modelType, model, n_samples=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dat.synth_data(modelType, model, n_samples=2)
#
# NameError: name 'dat' is not defined

# %% [markdown]
# # Analyse Data

# %% [markdown]
# **Create Residuals**

# %% [markdown]
# **Get best test**
