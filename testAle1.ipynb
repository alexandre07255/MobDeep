# %% [markdown]
# # Base: Algorithm 1

# %% [markdown]
# **Imports**

# %%
import utils as u
import models_generator as mod
import data_generator as dat
import analysis_generator as ana

# %% [markdown]
# # Generate Model

# %%
modelType = "timegan"
modelBroadType = 'gans'
model = "timegan_exp1.json"
exp_settings = u.load_experiment(model)
exp_id = exp_settings['exp_id']
print (exp_id)
print (exp_settings['tests'].keys())
u.creat_directories(exp_id, exp_settings)
mod.train_models("timegan", exp_settings)
# Out:
# exp_timegan
# dict_keys(['t1'])
# Directory already exists.  Continuing...
# Directory already exists.  Continuing...
# ...
# Joint networks training: 100%|██████████| 2/2 [00:47<00:00, 23.98s/it]
# Pausing execution for 10s

# %% [markdown]
# # Generate Synthdata

# %%
dat.synth_data(modelType, model, n_samples=2)
# Out:
# Opa funciona
# 2025-03-21 04:52:54.155870: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-21 04:52:54.226913: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2025-03-21 04:52:54.226976: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1835] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# ...

# %% [markdown]
# # Analyse Data

# %% [markdown]
# **Create Residuals**

# %%
ana.generate_residuals(model, modelBroadType, modelType, nn_params={'bs':200, 'e':50, 'v':False})
# Out:
# Model not found. Saving one at experiments/exp_timegan/exp_timegan.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/vs_code/MobDeeper/MobDeep/analysis_generator.py:223, in deep_residuals(exp_json, real_data, nn_params, exp_file)
#     222 try:
# --> 223   rnn_model = load_model(model_path)
#     224   X, y = split_sequence(real_data,n_steps=nn_params['n_steps'])
#
# File ~/vs_code/MobDeeper/MobDeep/.conda/lib/python3.9/site-packages/keras/saving/save.py:205, in load_model(filepath, custom_objects, compile, options)
#     204       if isinstance(filepath, str):
# --> 205         return saved_model_load.load(filepath, compile, options)
#     207 raise IOError(
#     208     'Unable to load model. Filepath is not an hdf5 file (or h5py is not '
#     209     'available) or SavedModel.')
#
# ...

# %% [markdown]
# **Get best test**
