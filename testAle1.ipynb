# %% [markdown]
# # Base: Algorithm 1

# %% [markdown]
# **Imports**

# %%
import utils as u
import models_generator as mod
import data_generator as dat
import analysis_generator as ana

# %% [markdown]
# # Generate Model

# %%
modelType = "timegan"
model = "timegan_exp1.json"
exp_settings = u.load_experiment(model)
exp_id = exp_settings['exp_id']
print (exp_id)
print (exp_settings['tests'].keys())
u.creat_directories(exp_id, exp_settings)
mod.train_models("timegan", exp_settings)
# Out:
# exp_timegan
# dict_keys(['t1'])
# Directory already exists.  Continuing...
# Directory already exists.  Continuing...
# Emddeding network training: 100%|██████████| 2/2 [00:04<00:00,  2.35s/it]
# Supervised network training: 100%|██████████| 2/2 [00:03<00:00,  1.71s/it]
# Joint networks training: 100%|██████████| 2/2 [00:43<00:00, 21.76s/it]
# Pausing execution for 10s

# %% [markdown]
# # Generate Synthdata

# %%
dat.synth_data(modelType, model, n_samples=2)
# Out:
# Opa funciona
# 2025-03-07 07:13:33.092930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-07 07:13:33.149303: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2025-03-07 07:13:33.149362: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1835] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-03-07 07:13:33.160162: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Synthetic data generation:   0%|          | 0/3 [00:00<?, ?it/s]2025-03-07 07:13:43.192544: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Synthetic data generation: 100%|██████████| 3/3 [00:00<00:00,  5.23it/s]
# Synthetic data generation: 100%|██████████| 3/3 [00:00<00:00,  6.55it/s]

# %% [markdown]
# # Analyse Data

# %% [markdown]
# **Create Residuals**

# %% [markdown]
# **Get best test**
